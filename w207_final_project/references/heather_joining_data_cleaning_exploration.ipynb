# %%
import pandas as pd
import datetime
import missingno
import os
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import pytz

est = pytz.timezone('US/Eastern')
utc = pytz.utc

# %% [markdown]
# <b>Load Data and Join Initial Datasets, Clean as Needed</b>

# %%
#note for david's structure
cd = os.getcwd()
raw_data_directory_path = "/".join(cd.split("/")[:-1]) + "/data/raw/"
processed_data_directory_path = "/".join(cd.split("/")[:-1]) + "/data/processed/"

# %%
#enter your appriate path/paths here if the above doesn't work, up to the data folder you put the 
#raw and processed data folders in
                            #ENTER THE BEGINNING OF YOur PATH TO RAW AND PROCESSED HERE
raw_data_directory_path = 'C:/Users/heath/Desktop/W207/w207_final_project/w207_final_project/data/raw/'
processed_data_directory_path = 'C:/Users/heath/Desktop/W207/w207_final_project/w207_final_project/data/processed/'

# %% [markdown]
# <b>Get Tweet Datasets and Join </b>

# %%
tweets = pd.read_csv(raw_data_directory_path+'tweet_data/Tweet.csv')

# %%
company_tweets = pd.read_csv(raw_data_directory_path +'tweet_data/Company_Tweet.csv')

# %%
company = pd.read_csv(raw_data_directory_path +'tweet_data/Company.csv')

# %%
tweet_combo = pd.merge(tweets, company_tweets)

# %%
tweet_combo = pd.merge(tweet_combo, company)

# %%
tweet_combo.ticker_symbol.unique()
# Out:
# array(['AAPL', 'AMZN', 'TSLA', 'MSFT', 'GOOG', 'GOOGL'], dtype=object)

# %% [markdown]
# <b>Get stock data for our tweet companies and join </b>

# %%
companynasdaq = pd.read_csv(raw_data_directory_path + 'stock_data/Company.csv')

# %%
company_val = pd.read_csv(raw_data_directory_path+'stock_data/CompanyValues.csv')

# %%
company_val.day_date = pd.to_datetime(company_val.day_date,format='%Y-%m-%d %H:%M:%S')

# %%
#we want to drop the duplicates and keep the max per day with hour min sec, and then convert back to just looking at the day.
#keeping the day makes it easier to join the datasets on tweets that day compared to market close and adjustment per day
company_val .sort_values(['day_date'], ascending=True, inplace=True)
company_val = company_val.drop_duplicates(subset = ['day_date', 'ticker_symbol'], keep = 'last')

# %%
#get stock data 2015 plus to match our tweet data dates
company_val.day_date = pd.to_datetime(company_val.day_date,format='%Y-%m-%d')
company_val = company_val.loc[company_val.day_date >= '2015-01-01']

# %%
#check to make sure filter worked
company_val.day_date.min()
# Out:
# Timestamp('2015-01-01 00:00:00')

# %%
stock_prices = pd.merge(company_val, companynasdaq)

# %%
stock_prices
stock_prices.sort_values(['day_date'], ascending=True, inplace=True)

# %%
stock_prices.ticker_symbol.unique() #keeping GOOG and GOOGL for now since both in twitter data
# Out:
# array(['MSFT', 'TSLA', 'GOOG', 'AMZN', 'GOOGL', 'AAPL'], dtype=object)

# %%
stock_prices.company_name.unique()
# Out:
# array(['Microsoft', 'Tesla Inc', 'Google Inc', 'Amazon.com', 'apple'],
#       dtype=object)

# %%
#replacing 'GOOG' and 'GOOGL' are actually two different stocks from Google Inc.
#https://seekingalpha.com/article/4430928-which-google-stock-is-a-better-buy-goog-or-googl

# %%
#also we have duplicates every day now so just keep the latest one
stock_prices = stock_prices.drop_duplicates(subset = ['day_date', 'ticker_symbol'], keep = 'last')

# %%
tickers = list(stock_prices.ticker_symbol.unique())
tickers
# Out:
# ['MSFT', 'TSLA', 'GOOG', 'AMZN', 'GOOGL', 'AAPL']

# %%
#create stock return % change from previous day
stock_prices['return'] = stock_prices.groupby('ticker_symbol')['close_value'].pct_change()

# %%
#need to convert the tweet post date to date time and also account for stock prices being in est, so make tweets est

# %%
tweet_combo.post_date = tweet_combo.post_date.apply(lambda x: datetime.datetime.fromtimestamp(x).astimezone(est).strftime('%Y-%m-%d'))
tweet_combo.post_date = pd.to_datetime(tweet_combo.post_date, format='%Y-%m-%d')

# %%
len(tweet_combo)
# Out:
# 4336445

# %% [markdown]
# <b>Add S&P 500 Data</b>

# %%
sp500 = pd.read_csv(raw_data_directory_path+'stock_data/SP500_historical.csv')

# %%
sp500.Date = pd.to_datetime(sp500.Date)
sp500.sort_values(['Date'], ascending=True, inplace=True)

# %%
sp500.columns = ['day_date', 'sp_open', 'sp_high', 'sp_low', 'sp_close']

# %%
sp500['sp_pct_return'] = sp500['sp_close'].pct_change()

# %%
spcols = ['day_date', 'sp_close', 'sp_pct_return']
sp500 = sp500[spcols]

# %% [markdown]
# <b>Combine S&P 500 and Stock Data </b>

# %%
stock_prices = pd.merge(stock_prices, sp500)

# %%
stock_prices.head(50)
# Out:
#    ticker_symbol   day_date  close_value    volume  open_value  high_value  \
# 0           TSLA 2015-01-02      219.310   4753239      222.87    223.2500
# 1           GOOG 2015-01-02      524.810   1444809      529.01    531.2700
# 2           AAPL 2015-01-02      109.330  53143770      111.39    111.4400
# 3           MSFT 2015-01-02       46.760  27843560       46.66     47.4200
# 4           AMZN 2015-01-02      308.520   2785167      312.58    314.7500
# 5          GOOGL 2015-01-02      529.550   1325271      532.60    535.8000
# 6          GOOGL 2015-01-05      519.460   2054120      527.15    527.9899
# 7           GOOG 2015-01-05      513.870   2049303      523.26    524.3300
# 8           AAPL 2015-01-05      106.250  64210880      108.29    108.6500
# 9           TSLA 2015-01-05      210.090   5355485      214.55    216.5000
# 10          AMZN 2015-01-05      302.190   2768215      307.01    308.3800
# 11          MSFT 2015-01-05       46.325  39667400       46.37     46.7300
# 12         GOOGL 2015-01-06      506.640   2727897      520.50    521.2100
# 13          TSLA 2015-01-06      211.280   6257651      210.06    214.2000
# 14          AMZN 2015-01-06      295.290   3511003      302.24    303.0000
# 15          AAPL 2015-01-06      106.260  65682250      106.54    107.4300
# 16          MSFT 2015-01-06       45.650  36434980       46.38     46.7490
# 17          GOOG 2015-01-06      501.960   2884479      515.00    516.1750
# 18          TSLA 2015-01-07      210.950   2965330      213.35    214.7800
# 19          AAPL 2015-01-07      107.750  39983350      107.20    108.2000
# 20         GOOGL 2015-01-07      505.150   2345062      510.95    511.4900
# 21          AMZN 2015-01-07      298.420   2630671      297.50    301.2800
# 22          GOOG 2015-01-07      501.100   2053750      507.00    507.2440
# 23          MSFT 2015-01-07       46.230  29103920       45.98     46.4600
# 24          AAPL 2015-01-08      111.890  59168760      109.23    112.1500
# 25          AMZN 2015-01-08      300.460   3087475      300.32    303.1400
# 26          TSLA 2015-01-08      210.615   3434901      212.81    213.7999
# 27         GOOGL 2015-01-08      506.910   3661816      501.51    507.5000
# 28          MSFT 2015-01-08       47.590  29634030       46.75     47.7499
# 29          GOOG 2015-01-08      502.680   3341935      497.99    503.4800
# 30          AMZN 2015-01-09      296.930   2589914      301.48    302.8700
# 31          TSLA 2015-01-09      206.660   4591310      208.92    209.9800
# 32         GOOGL 2015-01-09      500.720   2097137      508.18    508.6000
# 33          AAPL 2015-01-09      112.010  53645730      112.67    113.2500
# 34          MSFT 2015-01-09       47.190  23942750       47.61     47.8200
# 35          GOOG 2015-01-09      496.170   2063743      504.76    504.9200
# 36          GOOG 2015-01-12      492.550   2317278      494.94    495.9760
# 37          AAPL 2015-01-12      109.250  49571170      112.60    112.6300
# 38          AMZN 2015-01-12      291.410   3406438      297.56    298.5100
# 39          MSFT 2015-01-12       46.600  23623970       47.42     47.5400
# 40         GOOGL 2015-01-12      497.060   2855348      499.24    500.2800
# 41          TSLA 2015-01-12      202.210   5945607      203.05    204.4700
# 42          AAPL 2015-01-13      110.220  66969980      111.43    112.8000
# 43          TSLA 2015-01-13      204.250   4247704      203.32    207.6100
# 44          AMZN 2015-01-13      294.740   4135336      297.48    301.4976
# 45          GOOG 2015-01-13      496.180   2365612      498.84    502.9800
# 46         GOOGL 2015-01-13      501.800   3049845      502.57    508.6000
# 47          MSFT 2015-01-13       46.355  35258300       46.97     47.9100
# 48          MSFT 2015-01-14       45.955  29713190       45.96     46.2400
# 49          AAPL 2015-01-14      109.800  48728190      109.04    110.4900
#
#     low_value company_name    return  sp_close  sp_pct_return
# 0    213.2600    Tesla Inc -0.013938   2058.20            NaN
# 1    524.1000   Google Inc -0.003021   2058.20            NaN
# 2    107.3500        apple -0.009513   2058.20            NaN
# 3     46.5400    Microsoft  0.006674   2058.20            NaN
# 4    306.9601   Amazon.com -0.005897   2058.20            NaN
# 5    527.8800   Google Inc -0.002092   2058.20            NaN
# 6    517.7500   Google Inc -0.019054   2020.58      -0.018278
# 7    513.0600   Google Inc -0.020846   2020.58      -0.018278
# 8    105.4100        apple -0.028172   2020.58      -0.018278
# 9    207.1626    Tesla Inc -0.042041   2020.58      -0.018278
# 10   300.8500   Amazon.com -0.020517   2020.58      -0.018278
# 11    46.2500    Microsoft -0.009303   2020.58      -0.018278
# 12   505.5500   Google Inc -0.024679   2002.61      -0.008893
# 13   204.2100    Tesla Inc  0.005664   2002.61      -0.008893
# 14   292.3800   Amazon.com -0.022833   2002.61      -0.008893
# 15   104.6300        apple  0.000094   2002.61      -0.008893
# 16    45.5400    Microsoft -0.014571   2002.61      -0.008893
# 17   501.0500   Google Inc -0.023177   2002.61      -0.008893
# 18   209.7800    Tesla Inc -0.001562   2025.90       0.011630
# 19   106.6950        apple  0.014022   2025.90       0.011630
# 20   503.6500   Google Inc -0.002941   2025.90       0.011630
# 21   295.3300   Amazon.com  0.010600   2025.90       0.011630
# 22   499.6500   Google Inc -0.001713   2025.90       0.011630
# 23    45.4900    Microsoft  0.012705   2025.90       0.011630
# 24   108.7000        apple  0.038422   2062.14       0.017888
# 25   296.1100   Amazon.com  0.006836   2062.14       0.017888
# 26   210.0100    Tesla Inc -0.001588   2062.14       0.017888
# 27   495.0200   Google Inc  0.003484   2062.14       0.017888
# 28    46.7200    Microsoft  0.029418   2062.14       0.017888
# 29   491.0000   Google Inc  0.003153   2062.14       0.017888
# 30   296.6800   Amazon.com -0.011749   2044.81      -0.008404
# 31   204.9600    Tesla Inc -0.018778   2044.81      -0.008404
# 32   498.6500   Google Inc -0.012211   2044.81      -0.008404
# 33   110.2100        apple  0.001072   2044.81      -0.008404
# 34    46.9000    Microsoft -0.008405   2044.81      -0.008404
# 35   494.7900   Google Inc -0.012951   2044.81      -0.008404
# 36   487.5600   Google Inc -0.007296   2028.26      -0.008094
# 37   108.8000        apple -0.024641   2028.26      -0.008094
# 38   289.2810   Amazon.com -0.018590   2028.26      -0.008094
# 39    46.3600    Microsoft -0.012503   2028.26      -0.008094
# 40   490.9100   Google Inc -0.007309   2028.26      -0.008094
# 41   199.2500    Tesla Inc -0.021533   2028.26      -0.008094
# 42   108.9100        apple  0.008879   2023.03      -0.002579
# 43   200.9110    Tesla Inc  0.010089   2023.03      -0.002579
# 44   293.2300   Amazon.com  0.011427   2023.03      -0.002579
# 45   492.3900   Google Inc  0.007370   2023.03      -0.002579
# 46   497.2600   Google Inc  0.009536   2023.03      -0.002579
# 47    46.0600    Microsoft -0.005258   2023.03      -0.002579
# 48    45.6200    Microsoft -0.008629   2011.27      -0.005813
# 49   108.5000        apple -0.003811   2011.27      -0.005813

# %% [markdown]
# <b>Join Final Datasets - Stock Data with S&P 500 and Tweet Data </b>

# %%
#join on date and ticker symbol to get the stock price for the company for the date of the post
final_df = pd.merge(tweet_combo, stock_prices, left_on = ['post_date', 'ticker_symbol'], right_on = ['day_date', 'ticker_symbol'])

# %%
final_df
# Out:
#                     tweet_id           writer  post_date  \
# 0         550886375860736000            TCBFx 2015-01-02
# 1         550887748803256320       FractalHIS 2015-01-02
# 2         550888743654400000         pricatti 2015-01-02
# 3         550889239680790528     stock_forums 2015-01-02
# 4         550889252104327168   Chasing__Stars 2015-01-02
# ...                      ...              ...        ...
# 3705416  1212142968037138432       faang_gang 2019-12-31
# 3705417  1212149780471853057  harveyrosenblum 2019-12-31
# 3705418  1212150279656890374   luke_sosnowski 2019-12-31
# 3705419  1212150864066023427  Flower_Power_67 2019-12-31
# 3705420  1212157343351238656     naashonomics 2019-12-31
#
#                                                       body  comment_num  \
# 0        The Closing Bell is out! http://paper.li/BonaC...            0
# 1        $AAPL #AAPL Looking forward to seeing how this...            0
# 2        #Balances #resultados #cartera #portfolio$aapl...            0
# 3        $PNOW Percent Change Updated Thursday, January...            0
# 4        $PLGC Stock Message Board Updated Thursday, Ja...            0
# ...                                                    ...          ...
# 3705416                             $GOOGL also flat today            1
# 3705417  If this continues then the market will be enti...            0
# 3705418  Great day and years end over at #TRICKTRADES m...            1
# 3705419  #FastMoneyEspressoFINAL TRADES:Steve Grasso —>...            0
# 3705420                  $FB $AMZN $GOOGL $NFLX #FANG 2019            0
#
#          retweet_num  like_num ticker_symbol company_name_x   day_date  \
# 0                  0         0          AAPL          apple 2015-01-02
# 1                  1         1          AAPL          apple 2015-01-02
# 2                  0         1          AAPL          apple 2015-01-02
# 3                  0         0          AAPL          apple 2015-01-02
# 4                  0         0          AAPL          apple 2015-01-02
# ...              ...       ...           ...            ...        ...
# 3705416            0         0         GOOGL     Google Inc 2019-12-31
# 3705417            0         2         GOOGL     Google Inc 2019-12-31
# 3705418            2         7         GOOGL     Google Inc 2019-12-31
# 3705419            1         4         GOOGL     Google Inc 2019-12-31
# 3705420            0         0         GOOGL     Google Inc 2019-12-31
#
#          close_value    volume  open_value  high_value  low_value  \
# 0             109.33  53143770      111.39      111.44     107.35
# 1             109.33  53143770      111.39      111.44     107.35
# 2             109.33  53143770      111.39      111.44     107.35
# 3             109.33  53143770      111.39      111.44     107.35
# 4             109.33  53143770      111.39      111.44     107.35
# ...              ...       ...         ...         ...        ...
# 3705416      1339.39    976061     1335.79     1340.66    1332.13
# 3705417      1339.39    976061     1335.79     1340.66    1332.13
# 3705418      1339.39    976061     1335.79     1340.66    1332.13
# 3705419      1339.39    976061     1335.79     1340.66    1332.13
# 3705420      1339.39    976061     1335.79     1340.66    1332.13
#
#         company_name_y    return  sp_close  sp_pct_return
# 0                apple -0.009513   2058.20            NaN
# 1                apple -0.009513   2058.20            NaN
# 2                apple -0.009513   2058.20            NaN
# 3                apple -0.009513   2058.20            NaN
# 4                apple -0.009513   2058.20            NaN
# ...                ...       ...       ...            ...
# 3705416     Google Inc -0.000239   3230.78       0.002946
# 3705417     Google Inc -0.000239   3230.78       0.002946
# 3705418     Google Inc -0.000239   3230.78       0.002946
# 3705419     Google Inc -0.000239   3230.78       0.002946
# 3705420     Google Inc -0.000239   3230.78       0.002946
#
# [3705421 rows x 19 columns]

# %%
#lost x amount of tweets when merging stock data (171) - keeping days where stocks are traded - sp500 only contains trade days

# %%
len(tweet_combo) - len(final_df)
# Out:
# 631024

# %%
final_df = final_df.rename(columns = {'company_name_x': 'company_name'})
final_df = final_df.drop(['company_name_y'], axis=1)

# %%
final_df.head(895)
# Out:
#                tweet_id           writer  post_date  \
# 0    550886375860736000            TCBFx 2015-01-02
# 1    550887748803256320       FractalHIS 2015-01-02
# 2    550888743654400000         pricatti 2015-01-02
# 3    550889239680790528     stock_forums 2015-01-02
# 4    550889252104327168   Chasing__Stars 2015-01-02
# ..                  ...              ...        ...
# 890  551238715277062144       intltrade2 2015-01-02
# 891  551238755189661696       kevinbantz 2015-01-02
# 892  551238883946811393        Sara20992 2015-01-02
# 893  551239679165476864  SwingTradeAlert 2015-01-02
# 894  551966835382710272          IHPosts 2015-01-05
#
#                                                   body  comment_num  \
# 0    The Closing Bell is out! http://paper.li/BonaC...            0
# 1    $AAPL #AAPL Looking forward to seeing how this...            0
# 2    #Balances #resultados #cartera #portfolio$aapl...            0
# 3    $PNOW Percent Change Updated Thursday, January...            0
# 4    $PLGC Stock Message Board Updated Thursday, Ja...            0
# ..                                                 ...          ...
# 890                             testing this buy $AAPL            0
# 891  Commented on StockTwits: sunset better but $AA...            0
# 892  Free 5€ in account balance for first 100.000 m...            0
# 893  IBD:Apple, Other IBD 50 Stock Leaders Close Be...            0
# 894  Stock Contest!! Pick $COP and WIN a FREE Table...            0
#
#      retweet_num  like_num ticker_symbol company_name   day_date  close_value  \
# 0              0         0          AAPL        apple 2015-01-02       109.33
# 1              1         1          AAPL        apple 2015-01-02       109.33
# 2              0         1          AAPL        apple 2015-01-02       109.33
# 3              0         0          AAPL        apple 2015-01-02       109.33
# 4              0         0          AAPL        apple 2015-01-02       109.33
# ..           ...       ...           ...          ...        ...          ...
# 890            0         0          AAPL        apple 2015-01-02       109.33
# 891            0         0          AAPL        apple 2015-01-02       109.33
# 892            0         0          AAPL        apple 2015-01-02       109.33
# 893            2         1          AAPL        apple 2015-01-02       109.33
# 894            0         0          AAPL        apple 2015-01-05       106.25
#
#        volume  open_value  high_value  low_value    return  sp_close  \
# 0    53143770      111.39      111.44     107.35 -0.009513   2058.20
# 1    53143770      111.39      111.44     107.35 -0.009513   2058.20
# 2    53143770      111.39      111.44     107.35 -0.009513   2058.20
# 3    53143770      111.39      111.44     107.35 -0.009513   2058.20
# 4    53143770      111.39      111.44     107.35 -0.009513   2058.20
# ..        ...         ...         ...        ...       ...       ...
# 890  53143770      111.39      111.44     107.35 -0.009513   2058.20
# 891  53143770      111.39      111.44     107.35 -0.009513   2058.20
# 892  53143770      111.39      111.44     107.35 -0.009513   2058.20
# 893  53143770      111.39      111.44     107.35 -0.009513   2058.20
# 894  64210880      108.29      108.65     105.41 -0.028172   2020.58
#
#      sp_pct_return
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 890            NaN
# 891            NaN
# 892            NaN
# 893            NaN
# 894      -0.018278
#
# [895 rows x 18 columns]

# %% [markdown]
# <b>Export to appropriate path here</b>

# %%
#note that cleaned data features include:
    #joining tweet datasets on tweet IDs and then to stock data on post date (tweet data) and day date (stock data) and ticker symbol
    #making return per stock (percent change from previous day) - make over week for final dataset
    #converting datetimes and considerations for est
    #keeping stock data greater than 2015 to match our tweet data
    #acsending date sorting
    #added S&P 500 data - close value and percent change from previous day

# %%
final_df.to_csv(processed_data_directory_path+'cleaned_data.csv')

# %% [markdown]
# <b>Data Exploration ..</b>

# %%
#note I swear this works but it just broke on my system's memory
#produces a nice heat style of missing data - I would say we don't really have missing data in the final df
missingno.matrix(final_df,figsize=(10,5), fontsize=12)

# %%
#cool that we are actually not missing a lot of data, basically have full data for all values.

# %%
final_df.describe()
# Out:
#            tweet_id   comment_num   retweet_num      like_num   close_value  \
# count  3.705421e+06  3.705421e+06  3.705421e+06  3.705421e+06  3.705421e+06
# mean   8.825025e+17  2.869946e-01  6.177506e-01  2.027946e+00  4.601062e+02
# std    1.925688e+17  1.868682e+00  7.045150e+00  1.339141e+01  4.657105e+02
# min    5.508798e+17  0.000000e+00  0.000000e+00  0.000000e+00  4.029000e+01
# 25%    7.195717e+17  0.000000e+00  0.000000e+00  0.000000e+00  1.287000e+02
# 50%    8.793614e+17  0.000000e+00  0.000000e+00  0.000000e+00  2.550100e+02
# 75%    1.054324e+18  0.000000e+00  0.000000e+00  1.000000e+00  7.042400e+02
# max    1.212160e+18  6.310000e+02  9.990000e+02  9.990000e+02  2.039510e+03
#
#              volume    open_value    high_value     low_value        return  \
# count  3.705421e+06  3.705421e+06  3.705421e+06  3.705421e+06  3.705421e+06
# mean   2.035185e+07  4.600215e+02  4.651276e+02  4.545439e+02  1.243132e-03
# std    2.263473e+07  4.657048e+02  4.700767e+02  4.607222e+02  2.608636e-02
# min    3.475180e+05  4.034000e+01  4.074000e+01  3.972000e+01 -1.390153e-01
# 25%    3.769453e+06  1.285800e+02  1.296200e+02  1.278500e+02 -8.679704e-03
# 50%    1.036460e+07  2.550500e+02  2.590000e+02  2.501800e+02  1.008488e-03
# 75%    3.059640e+07  7.036700e+02  7.116000e+02  6.968000e+02  1.152093e-02
# max    1.691150e+08  2.038110e+03  2.050500e+03  2.013000e+03  1.766923e-01
#
#            sp_close  sp_pct_return
# count  3.705421e+06   3.703729e+06
# mean   2.451504e+03   2.834690e-04
# std    3.605926e+02   8.613595e-03
# min    1.829080e+03  -4.097924e-02
# 25%    2.102150e+03  -2.986777e-03
# 50%    2.432540e+03   3.734622e-04
# 75%    2.784700e+03   4.620139e-03
# max    3.240020e+03   4.959381e-02

# %%
final_df.groupby(final_df["post_date"].dt.month).count().plot(kind="bar")
